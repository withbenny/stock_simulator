# %%
import stock

# %%
config = stock.ConfigLoader('config.json', 'alphavantage')

# %%
ticker = stock.GetTicker('GOOG', config)

# %%
ticker.latest_data(date='2024-01-01', interval='5min', time_series='TIME_SERIES_INTRADAY')

# %%
ticker.long_data(start_date='2020-09-01', end_date='2024-09-01', interval='5min')

# %%
ticker.get_news(topics=None, time_from='20240921T1315', num=1000, sort='EARLIEST')
# Out:
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=GOOG&time_from=20240921T1315&limit=1000&sort=EARLIEST&apikey=LRF0ZE43TBGOE44N

# %%
ticker.long_data('2022-09', '2022-12')

# %%
ticker.news_analysis('GOOG_news20240911T0820.json')
# Out:
# {'total_news': 19,
#  'sentiment_percentages': {'Bearish': 0.0,
#   'Somewhat-Bearish': 0.0,
#   'Neutral': 42.10526315789473,
#   'Somewhat-Bullish': 31.57894736842105,
#   'Bullish': 26.31578947368421},
#  'pessimistic_percentage': 0.0,
#  'neutral_percentage': 42.10526315789473,
#  'optimistic_percentage': 57.89473684210527,
#  'unweighted_avg_sentiment': 0.1973056315789474,
#  'weighted_avg_sentiment': 0.08950965486005265,
#  'overall_sentiment': 'Somewhat-Bullish'}
