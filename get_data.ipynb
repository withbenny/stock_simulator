# %%
import stock

# %%
config = stock.ConfigLoader('config.json', 'alphavantage')

# %%
ticker = stock.GetTicker('NVDA', config)

# %%
ticker.latest_data(date='2024-01-01', interval='5min', time_series='TIME_SERIES_INTRADAY')

# %%
ticker.long_data(start_date='2020-09-01', end_date='2024-09-01', interval='5min')

# %%
ticker.getNews(topics=None, time_from='20241121T0519', num=1000, sort='EARLIEST')
# Out:
# https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=NVDA&time_from=20241121T0519&limit=1000&sort=EARLIEST&apikey=LRF0ZE43TBGOE44N

# %%
ticker.long_data('2022-09', '2022-12')

# %%
ticker.newsAnalysis('AAPL_news20240101T0000.json')
# Out:
# {'total_news': 693,
#  'sentiment_percentages': {'Bearish': 1.0101010101010102,
#   'Somewhat-Bearish': 6.349206349206349,
#   'Neutral': 49.2063492063492,
#   'Somewhat-Bullish': 29.292929292929294,
#   'Bullish': 14.14141414141414},
#  'pessimistic_percentage': 7.35930735930736,
#  'neutral_percentage': 49.2063492063492,
#  'optimistic_percentage': 43.43434343434344,
#  'unweighted_avg_sentiment': 0.13952238239538248,
#  'weighted_avg_sentiment': 0.06380700256846605,
#  'overall_sentiment': 'Neutral'}
