# %%
from utils import GetDataset
GetDataset('AMZN_news20241108T1612.json', 'AMZN_7.csv').get('AMZN')

# %%
from utils import CombineDataset
CombineDataset().multi_combine("AMZN_*.csv", "AMZN.csv")

# %%
CombineDataset().combine2("AAPL_filtered.csv", "TSLA_filtered.csv", "DATA.csv")

# %%
from utils import Analysis

# %%
Analysis('data\AMZN\AMZN_cleaned.csv').compute_source()
# Out:
#                          source  count
# 0                  www.fool.com   1954
# 1                 www.zacks.com   1165
# 2             www.investors.com    260
# 3           www.marketwatch.com     94
# 4              moneymorning.com     45
# 5                www.forbes.com     19
# 6                   www.cnn.com     17
# 7             www.kiplinger.com     16
# 8   markets.businessinsider.com     15
# 9       www.businessinsider.com     10
# 10                stocknews.com     10
# 11            cointelegraph.com      7
# 12            investingnews.com      6
# 13           www.prnewswire.com      4
# 14            aap.thestreet.com      4
# 15                   decrypt.co      3
# 16        www.globenewswire.com      3
# 17              edition.cnn.com      2
# 18                  www.upi.com      1
# 19        www.investorideas.com      1
#                          source  count
# 0                  www.fool.com   1954
# 1                 www.zacks.com   1165
# ...

# %%
Analysis('AMZN.csv').remove_resources()

# %%
Analysis('./data/TSLA/TSLA_cleaned.csv').get_empty()

# %%
Analysis('data\AMZN\AMZN_cleaned.csv').get_article()

# %%
Analysis('TSLA_cleaned.csv').dataset_filter(min_length=20, max_length=None, output_path='TSLA_filtered.csv')
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (2469 > 512). Running this sequence through the model will result in indexing errors

# %%
Analysis('TSLA_filtered.csv').get_max_token_length()
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (2469 > 512). Running this sequence through the model will result in indexing errors
# Max token length: 1822
# 1822
